# %% [markdown]
# # My Jupyter Notebook on IBM Wastson Studio

# %% [markdown]
# **Earnest Aaron**
#
# Data Analyst

# %% [markdown]
# *I have always had an interest in manipulating large data sets and trying to understand what decisions should be made because of how the data connects. I have typically focused on the area of education, there are a lot of variables in understanding what makes a child successful.*

# %% [markdown]
# ### The code below used caculate simple math problems.

# %%
58 + 9 * 5
# Out:
# 103

# %% [markdown]
# ~~Required Aspects~~
#
# This is a link to [Coursa](https://www.coursera.org/)
#
# ![Internet Cat](https://i0.wp.com/expmag.com/wp-content/uploads/2021/12/KYTG17.jpg?fit=1199%2C800&ssl=1)
